# %% [markdown]
# <img src="piwrf_logo.gif" width="350" align="center">

# %% [markdown]
# Pi-WRF is a community driven project to facilitate education/learning related to numerical weather prediction. The [Pi-WRF GitHub](https://github.com/NCAR/pi-wrf) repository contains the necessary components and instructions to both use and contribute to the Pi-WRF project.

# %%
import pytz
import datetime
import numpy as np
from tzwhere import tzwhere
import ipywidgets as widgets
from  ipyleaflet import (Map, 
                         basemaps,  
                         Marker)

# %% [markdown]
# # Domain selection:
# <p>Below is a map with a marker that is positioned at Boulder Colorado, the location of NCAR. You may zoom in or out using the +/- in the upper left of the map. You may grab and drag the blue marker to any location where you would like to center your gridbox.</p>

# %%
# coordinates default to Boulder, CO
center = [40.0150, -105.2705]
zoom = 2
n = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=center, zoom=zoom)
marker = Marker(location=center, draggable=True)
n.add_layer(marker);
display(n)
# Out:
# Map(center=[40.015, -105.2705], controls=(ZoomControl(options=['zoom_out_title', 'zoom_in_title', 'zoom_in_tex…

# %% [markdown]
# # Datetime range selection:
# <p>The cell below automatically generates a datetime range based on the current time of the timezone for the map marker. The times are rounded according to the model's expected input. Current times are rounded down to the most recent appropriate hour for a start time. The end time adds six hours to the start time. It is possible to manually set the start and end times at the end of the cell if desired.</p>

# %%
# function for rounding times
def round_hour(x, base=6):
    return x // base * base
# time range is generated automatically based on current time at time zone of map marker
from tzwhere import tzwhere
tzwhere = tzwhere.tzwhere()
timezone_str = tzwhere.tzNameAt(marker.location[0], marker.location[1])
timezone = pytz.timezone(timezone_str)
today = datetime.datetime.now(timezone)
now = today.time()
step = now
tomorrow = today
now = now.replace(hour = round_hour(now.hour))
start_time = str(today.strftime('%m')) + "-" \
    + str(today.strftime('%d')) + "-" \
    + str(today.year) + "-" \
    + str(now.strftime('%H'))
if now.hour >= 18:
    step = step.replace(hour = 0)
    tomorrow = tomorrow.replace(day = tomorrow.day + 1)
else: 
    step = now.replace(hour = (now.hour + 6))
end_time = str(today.strftime('%m')) + "-" \
    + str(tomorrow.strftime('%d')) + "-" \
    + str(today.year) + "-" \
    + step.strftime('%H')

# you may enter the start_time and end_time manually here
# you just neec to uncomment the start_time and end_time lines and modify them as desired
# format: MM-DD-YYYY-HH
# where hour may be 00, 06, 12, or 18
# start_time = '07-24-2021-12'
# end_time = '07-24-2021-18'
# print(start_time)
# print(end_time)

# %%
# %%bash -s "$start_time" "$end_time"
# sed -i /userstartdate=/c\\userstartdate="$1" /pi-wrf/run_wrf
# sed -i /userenddate=/c\\userenddate="$2" /pi-wrf/run_wrf

# %%
# gridbox dimensions
gridbox_width = 5
gridbox_height = 4
# generate variables for domain based on map marker
xlim = np.sort(np.array([(marker.location[1]-gridbox_width/2),(marker.location[1]+gridbox_width/2)]))
print(xlim) # longitude bounds
ylim = np.sort(np.array([(marker.location[0]-gridbox_height/2),(marker.location[0]+gridbox_height/2)]))
print(ylim) # latitude bounds
# Out:
# [-107.7705 -102.7705]
# [ 38.015  42.015]

# %%
# call set_domain with arguments based on map marker
# %cd ~/../pi-wrf/pi_wrf/pi_wrf
# %pwd
# %ls
from set_domain import set_domain
set_domain(xlim, ylim)
# Out:
# /pi-wrf/pi_wrf/pi_wrf
# Pages/     __init__.py            color_schemes.py  set_domain.py
# Runner.py  calculate_distance.py  map.pkl

# %% [markdown]
# # Initiate model
# <p>The model is initiated from the cell below. The above cells should have already been executed so the appropriate inputs will be available for the model. The model will take a few minutes to run. You should wait until it finishes running before proceeding to the following cells. The cell's number will show an asterisk '*' while it is still running.</p>

# %%
# %%bash
# cd ~/../pi-wrf/pi_wrf/pi_wrf
# ../../run_wrf
# Out:
# Downloading boundary condition for forecast hour 000
#
# Downloading boundary condition for forecast hour 006
# Parsed 28 entries in GEOGRID.TBL
# Processing domain 1 of 1
#   Processing XLAT and XLONG
#   Processing MAPFAC
#   Processing F and E
#   Processing ROTANG
#   Processing LANDUSEF
#   Calculating landmask from LANDUSEF ( WATER =  17  21 )
#   Processing HGT_M
#   Processing SOILTEMP
#   Processing SOILCTOP
#   Processing SCT_DOM
#   Processing SOILCBOT
#   Processing SCB_DOM
#   Processing ALBEDO12M
#   Processing GREENFRAC
#   Processing LAI12M
#   Processing SNOALB
#   Processing CON
#   Processing VAR
#   Processing OA1
#   Processing OA2
#   Processing OA3
#   Processing OA4
#   Processing OL1
#   Processing OL2
#   Processing OL3
#   Processing OL4
#
#   Optional fields not processed by geogrid:
#     VAR_SSO (priority=1, resolution='lowres', path='/pi-wrf/WRF_System/lib/WPS_GEOG/varsso_10m/')
#     LAKE_DEPTH (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/lake_depth/')
#     URB_PARAM (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/NUDAPT44_1km/')
#     FRC_URB2D (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/urbfrac_nlcd2011/')
#     IMPERV (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/nlcd2011_imp_ll_9s/')
#     CANFRA (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/nlcd2011_can_ll_9s/')
#     EROD (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/erod/')
#     CLAYFRAC (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/clayfrac_5m/')
#     SANDFRAC (priority=1, resolution='default', path='/pi-wrf/WRF_System/lib/WPS_GEOG/sandfrac_5m/')
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !  Successful completion of geogrid.        !
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  *** Starting program ungrib.exe ***
# Start_date =  2021-12-06_12:00:00 ,      End_date = 2021-12-06_18:00:00
# output format is WPS
# Path to intermediate files is ./
#
# ###############################################################################
#
# Inventory for date = 2021-12-06 12:00:00
#
# PRES   TT       UU       VV       RH       HGT      PSFC     PMSL     SM000010 SM010040 SM040100 SM100200 SM010200 ST000010 ST010040 ST040100 ST100200 ST010200 SEAICE   LANDSEA  LANDN    SOILHGT  SKINTEMP SNOW     SNOWH    UMAXW    VMAXW    PMAXW    PMAXWNN  TMAXW    HGTMAXW  UTROP    VTROP    PTROP    PTROPNN  TTROP    HGTTROP
# -------------------------------------------------------------------------------
# 2013.0  O        O        O        O        O        O        X        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O
# 2001.0  X        X        X        X        O        X        O        X        X        X        X        O        X        X        X        X        O        X        X        O        X        X        X        O        X        X        X        O        X        X        X        X        X        O        X        X
# 1000.0  X        X        X        X        X
#  975.0  X        X        X        X        X
#  950.0  X        X        X        X        X
#  925.0  X        X        X        X        X
#  900.0  X        X        X        X        X
#  850.0  X        X        X        X        X
#  800.0  X        X        X        X        X
#  750.0  X        X        X        X        X
#  700.0  X        X        X        X        X
#  650.0  X        X        X        X        X
#  600.0  X        X        X        X        X
#  550.0  X        X        X        X        X
#  500.0  X        X        X        X        X
#  450.0  X        X        X        X        X
#  400.0  X        X        X        X        X
#  350.0  X        X        X        X        X
#  300.0  X        X        X        X        X
#  250.0  X        X        X        X        X
#  200.0  X        X        X        X        X
#  150.0  X        X        X        X        X
#  100.0  X        X        X        X        X
#   70.0  X        X        X        X        X
#   50.0  X        X        X        X        X
#   40.0  X        X        X        X        X
#   30.0  X        X        X        X        X
#   20.0  X        X        X        X        X
#   15.0  X        X        X        X        X
#   10.0  X        X        X        X        X
#    7.0  X        X        X        X        X
#    5.0  X        X        X        X        X
#    3.0  X        X        X        X        X
#    2.0  X        X        X        X        X
#    1.0  X        X        X        X        X
# -------------------------------------------------------------------------------
#
# ###############################################################################
#
# Inventory for date = 2021-12-06 18:00:00
#
# PRES   TT       UU       VV       RH       HGT      PSFC     PMSL     SM000010 SM010040 SM040100 SM100200 SM010200 ST000010 ST010040 ST040100 ST100200 ST010200 SEAICE   LANDSEA  LANDN    SOILHGT  SKINTEMP SNOW     SNOWH    UMAXW    VMAXW    PMAXW    PMAXWNN  TMAXW    HGTMAXW  UTROP    VTROP    PTROP    PTROPNN  TTROP    HGTTROP
# -------------------------------------------------------------------------------
# 2013.0  O        O        O        O        O        O        X        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O
# 2001.0  X        X        X        X        O        X        O        X        X        X        X        O        X        X        X        X        O        X        X        O        X        X        X        O        X        X        X        O        X        X        X        X        X        O        X        X
# 1000.0  X        X        X        X        X
#  975.0  X        X        X        X        X
#  950.0  X        X        X        X        X
#  925.0  X        X        X        X        X
#  900.0  X        X        X        X        X
#  850.0  X        X        X        X        X
#  800.0  X        X        X        X        X
#  750.0  X        X        X        X        X
#  700.0  X        X        X        X        X
#  650.0  X        X        X        X        X
#  600.0  X        X        X        X        X
#  550.0  X        X        X        X        X
#  500.0  X        X        X        X        X
#  450.0  X        X        X        X        X
#  400.0  X        X        X        X        X
#  350.0  X        X        X        X        X
#  300.0  X        X        X        X        X
#  250.0  X        X        X        X        X
#  200.0  X        X        X        X        X
#  150.0  X        X        X        X        X
#  100.0  X        X        X        X        X
#   70.0  X        X        X        X        X
#   50.0  X        X        X        X        X
#   40.0  X        X        X        X        X
#   30.0  X        X        X        X        X
#   20.0  X        X        X        X        X
#   15.0  X        X        X        X        X
#   10.0  X        X        X        X        X
#    7.0  X        X        X        X        X
#    5.0  X        X        X        X        X
#    3.0  X        X        X        X        X
#    2.0  X        X        X        X        X
#    1.0  X        X        X        X        X
# -------------------------------------------------------------------------------
#
# ###############################################################################
#
# Inventory for date = 2021-12-06 12:00:00
#
# PRES   TT       UU       VV       RH       HGT      PSFC     PMSL     SM000010 SM010040 SM040100 SM100200 SM010200 ST000010 ST010040 ST040100 ST100200 ST010200 SEAICE   LANDSEA  LANDN    SOILHGT  SKINTEMP SNOW     SNOWH    UMAXW    VMAXW    PMAXW    PMAXWNN  TMAXW    HGTMAXW  UTROP    VTROP    PTROP    PTROPNN  TTROP    HGTTROP
# -------------------------------------------------------------------------------
# 2013.0  O        O        O        O        O        O        X        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O
# 2001.0  X        X        X        X        O        X        O        X        X        X        X        O        X        X        X        X        O        X        X        O        X        X        X        X        X        X        X        X        X        X        X        X        X        X        X        X
# 1000.0  X        X        X        X        X
#  975.0  X        X        X        X        X
#  950.0  X        X        X        X        X
#  925.0  X        X        X        X        X
#  900.0  X        X        X        X        X
#  850.0  X        X        X        X        X
#  800.0  X        X        X        X        X
#  750.0  X        X        X        X        X
#  700.0  X        X        X        X        X
#  650.0  X        X        X        X        X
#  600.0  X        X        X        X        X
#  550.0  X        X        X        X        X
#  500.0  X        X        X        X        X
#  450.0  X        X        X        X        X
#  400.0  X        X        X        X        X
#  350.0  X        X        X        X        X
#  300.0  X        X        X        X        X
#  250.0  X        X        X        X        X
#  200.0  X        X        X        X        X
#  150.0  X        X        X        X        X
#  100.0  X        X        X        X        X
#   70.0  X        X        X        X        X
#   50.0  X        X        X        X        X
#   40.0  X        X        X        X        X
#   30.0  X        X        X        X        X
#   20.0  X        X        X        X        X
#   15.0  X        X        X        X        X
#   10.0  X        X        X        X        X
#    7.0  X        X        X        X        X
#    5.0  X        X        X        X        X
#    3.0  X        X        X        X        X
#    2.0  X        X        X        X        X
#    1.0  X        X        X        X        X
# -------------------------------------------------------------------------------
#
# ###############################################################################
#
# Inventory for date = 2021-12-06 18:00:00
#
# PRES   TT       UU       VV       RH       HGT      PSFC     PMSL     SM000010 SM010040 SM040100 SM100200 SM010200 ST000010 ST010040 ST040100 ST100200 ST010200 SEAICE   LANDSEA  LANDN    SOILHGT  SKINTEMP SNOW     SNOWH    UMAXW    VMAXW    PMAXW    PMAXWNN  TMAXW    HGTMAXW  UTROP    VTROP    PTROP    PTROPNN  TTROP    HGTTROP
# -------------------------------------------------------------------------------
# 2013.0  O        O        O        O        O        O        X        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O        O
# 2001.0  X        X        X        X        O        X        O        X        X        X        X        O        X        X        X        X        O        X        X        O        X        X        X        X        X        X        X        X        X        X        X        X        X        X        X        X
# 1000.0  X        X        X        X        X
#  975.0  X        X        X        X        X
#  950.0  X        X        X        X        X
#  925.0  X        X        X        X        X
#  900.0  X        X        X        X        X
#  850.0  X        X        X        X        X
#  800.0  X        X        X        X        X
#  750.0  X        X        X        X        X
#  700.0  X        X        X        X        X
#  650.0  X        X        X        X        X
#  600.0  X        X        X        X        X
#  550.0  X        X        X        X        X
#  500.0  X        X        X        X        X
#  450.0  X        X        X        X        X
#  400.0  X        X        X        X        X
#  350.0  X        X        X        X        X
#  300.0  X        X        X        X        X
#  250.0  X        X        X        X        X
#  200.0  X        X        X        X        X
#  150.0  X        X        X        X        X
#  100.0  X        X        X        X        X
#   70.0  X        X        X        X        X
#   50.0  X        X        X        X        X
#   40.0  X        X        X        X        X
# ...
# Full level index =   23     Height = 13271.1 m      Thickness =  942.6 m
# Full level index =   24     Height = 14213.7 m      Thickness =  942.6 m
# Full level index =   25     Height = 15156.3 m      Thickness =  942.6 m
# Full level index =   26     Height = 16098.9 m      Thickness =  942.6 m
# Full level index =   27     Height = 17041.5 m      Thickness =  942.6 m
# Full level index =   28     Height = 17984.1 m      Thickness =  942.6 m
# Full level index =   29     Height = 18926.7 m      Thickness =  942.6 m
# Full level index =   30     Height = 19869.3 m      Thickness =  942.6 m
#   flag value of flag_qnwfa is            0
# No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# Timing for processing          0 s.
# Timing for output          2 s.
# Timing for loop #    1 =          2 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2021-12-06_18:00:00.0000, which is loop #   2 out of    2
#  configflags%julyr, %julday, %gmt:        2021         340   18.0000000
#  metgrid input_wrf.F first_date_input = 2021-12-06_18:00:00
#  metgrid input_wrf.F first_date_nml = 2021-12-06_12:00:00
# Timing for input          0 s.
#          flag_soil_layers read from met_em file is  1
# Turning off use of MAX WIND level data in vertical interpolation
# Turning off use of TROPOPAUSE level data in vertical interpolation
# Using sfcprs3 to compute psfc
#   flag value of flag_qnwfa is            0
# No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# Timing for processing          0 s.
#  LBC valid between these times 2021-12-06_12:00:00.0000 2021-12-06_18:00:00
# Timing for output          1 s.
# Timing for loop #    2 =          1 s.
# real_em: SUCCESS COMPLETE REAL_EM INIT
#
# Running WRF
#
# --- WARNING: traj_opt is zero, but num_traj is not zero; setting num_traj to zero.
# --- NOTE: sst_update is 0, setting io_form_auxinput4 = 0 and auxinput4_interval = 0 for all domains
# --- NOTE: grid_fdda is 0 for domain      1, setting gfdda interval and ending time to 0 for that domain.
# --- NOTE: both grid_sfdda and pxlsm_soil_nudge are 0 for domain      1, setting sgfdda interval and ending time to 0 for that domain.
# --- NOTE: obs_nudge_opt is 0 for domain      1, setting obs nudging interval and ending time to 0 for that domain.
# --- NOTE: bl_pbl_physics /= 4, implies mfshconv must be 0, resetting
# Need MYNN PBL for icloud_bl = 1, resetting to 0
# --- NOTE: RRTMG radiation is not used, setting:  o3input=0 to avoid data pre-processing
# *************************************
# Configuring physics suite 'conus'
#
#          mp_physics:      4*
#          cu_physics:      6
#       ra_lw_physics:      4
#       ra_sw_physics:      4
#      bl_pbl_physics:      2
#   sf_sfclay_physics:      2
#  sf_surface_physics:      2
#
# (* = option overrides suite setting)
# *************************************
# --- NOTE: RRTMG radiation is in use, setting:  levsiz=59, alevsiz=12, no_src_types=6
# --- NOTE: num_soil_layers has been set to      4
# WRF V3.9.1 MODEL
# DYNAMICS OPTION: Eulerian Mass Coordinate
#  alloc_space_field: domain            1 ,              13369112  bytes allocated
# med_initialdata_input: calling input_input
# Timing for processing wrfinput file (stream 0) for domain        1:    0.12338 elapsed seconds
# Max map factor in domain 1 =  1.06. Scale the dt in the model accordingly.
# INPUT LandUse = "MODIFIED_IGBP_MODIS_NOAH"
#  LANDUSE TYPE = "MODIFIED_IGBP_MODIS_NOAH" FOUND          33  CATEGORIES           2  SEASONS WATER CATEGORY =           17  SNOW CATEGORY =           15
# INITIALIZE THREE Noah LSM RELATED TABLES
# Skipping over LUTYPE = USGS
#  LANDUSE TYPE = MODIFIED_IGBP_MODIS_NOAH FOUND          20  CATEGORIES
#  INPUT SOIL TEXTURE CLASSIFICATION = STAS
#  SOIL TEXTURE CLASSIFICATION = STAS FOUND          19  CATEGORIES
# Timing for Writing wrfout_d01_2021-12-06_12:00:00 for domain        1:    2.33919 elapsed seconds
# Timing for processing lateral boundary for domain        1:    0.08753 elapsed seconds
# WRF NUMBER OF TILES FROM OMP_GET_MAX_THREADS =   4
#  Tile Strategy is not specified. Assuming 1D-Y
# WRF TILE   1 IS      1 IE     15 JS      1 JE      4
# WRF TILE   2 IS      1 IE     15 JS      5 JE      8
# WRF TILE   3 IS      1 IE     15 JS      9 JE     11
# WRF TILE   4 IS      1 IE     15 JS     12 JE     15
# WRF NUMBER OF TILES =   4
# Timing for main: time 2021-12-06_12:03:00 on domain   1:    3.98170 elapsed seconds
# Timing for main: time 2021-12-06_12:06:00 on domain   1:    0.33218 elapsed seconds
# Timing for main: time 2021-12-06_12:09:00 on domain   1:    0.33341 elapsed seconds
# Timing for main: time 2021-12-06_12:12:00 on domain   1:    0.34499 elapsed seconds
# Timing for main: time 2021-12-06_12:15:00 on domain   1:    0.32758 elapsed seconds
# Timing for main: time 2021-12-06_12:18:00 on domain   1:    0.35250 elapsed seconds
# Timing for main: time 2021-12-06_12:21:00 on domain   1:    0.31461 elapsed seconds
# Timing for main: time 2021-12-06_12:24:00 on domain   1:    0.38998 elapsed seconds
# Timing for main: time 2021-12-06_12:27:00 on domain   1:    0.39510 elapsed seconds
# Timing for main: time 2021-12-06_12:30:00 on domain   1:    0.32054 elapsed seconds
# Timing for main: time 2021-12-06_12:33:00 on domain   1:    0.96259 elapsed seconds
# Timing for main: time 2021-12-06_12:36:00 on domain   1:    0.35275 elapsed seconds
# Timing for main: time 2021-12-06_12:39:00 on domain   1:    0.33840 elapsed seconds
# Timing for main: time 2021-12-06_12:42:00 on domain   1:    0.36685 elapsed seconds
# Timing for main: time 2021-12-06_12:45:00 on domain   1:    0.32680 elapsed seconds
# Timing for main: time 2021-12-06_12:48:00 on domain   1:    0.42981 elapsed seconds
# Timing for main: time 2021-12-06_12:51:00 on domain   1:    0.37343 elapsed seconds
# Timing for main: time 2021-12-06_12:54:00 on domain   1:    0.30451 elapsed seconds
# Timing for main: time 2021-12-06_12:57:00 on domain   1:    0.34347 elapsed seconds
# Timing for main: time 2021-12-06_13:00:00 on domain   1:    0.34136 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_13:00:00 for domain        1:    0.08974 elapsed seconds
# Timing for main: time 2021-12-06_13:03:00 on domain   1:    1.04911 elapsed seconds
# Timing for main: time 2021-12-06_13:06:00 on domain   1:    0.33531 elapsed seconds
# Timing for main: time 2021-12-06_13:09:00 on domain   1:    0.30759 elapsed seconds
# Timing for main: time 2021-12-06_13:12:00 on domain   1:    0.32316 elapsed seconds
# Timing for main: time 2021-12-06_13:15:00 on domain   1:    0.29387 elapsed seconds
# Timing for main: time 2021-12-06_13:18:00 on domain   1:    0.33057 elapsed seconds
# Timing for main: time 2021-12-06_13:21:00 on domain   1:    0.31753 elapsed seconds
# Timing for main: time 2021-12-06_13:24:00 on domain   1:    0.33353 elapsed seconds
# Timing for main: time 2021-12-06_13:27:00 on domain   1:    0.28813 elapsed seconds
# Timing for main: time 2021-12-06_13:30:00 on domain   1:    0.33806 elapsed seconds
# Timing for main: time 2021-12-06_13:33:00 on domain   1:    0.91504 elapsed seconds
# Timing for main: time 2021-12-06_13:36:00 on domain   1:    0.32205 elapsed seconds
# Timing for main: time 2021-12-06_13:39:00 on domain   1:    0.28868 elapsed seconds
# Timing for main: time 2021-12-06_13:42:00 on domain   1:    0.30431 elapsed seconds
# Timing for main: time 2021-12-06_13:45:00 on domain   1:    0.33440 elapsed seconds
# Timing for main: time 2021-12-06_13:48:00 on domain   1:    0.31163 elapsed seconds
# Timing for main: time 2021-12-06_13:51:00 on domain   1:    0.31197 elapsed seconds
# Timing for main: time 2021-12-06_13:54:00 on domain   1:    0.36730 elapsed seconds
# Timing for main: time 2021-12-06_13:57:00 on domain   1:    0.32538 elapsed seconds
# Timing for main: time 2021-12-06_14:00:00 on domain   1:    0.32398 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_14:00:00 for domain        1:    0.09187 elapsed seconds
# Timing for main: time 2021-12-06_14:03:00 on domain   1:    1.87289 elapsed seconds
# Timing for main: time 2021-12-06_14:06:00 on domain   1:    0.33670 elapsed seconds
# Timing for main: time 2021-12-06_14:09:00 on domain   1:    0.35325 elapsed seconds
# Timing for main: time 2021-12-06_14:12:00 on domain   1:    0.33899 elapsed seconds
# Timing for main: time 2021-12-06_14:15:00 on domain   1:    0.32065 elapsed seconds
# Timing for main: time 2021-12-06_14:18:00 on domain   1:    0.32138 elapsed seconds
# Timing for main: time 2021-12-06_14:21:00 on domain   1:    0.32094 elapsed seconds
# Timing for main: time 2021-12-06_14:24:00 on domain   1:    0.31984 elapsed seconds
# Timing for main: time 2021-12-06_14:27:00 on domain   1:    0.38650 elapsed seconds
# Timing for main: time 2021-12-06_14:30:00 on domain   1:    0.36515 elapsed seconds
# Timing for main: time 2021-12-06_14:33:00 on domain   1:    2.06018 elapsed seconds
# Timing for main: time 2021-12-06_14:36:00 on domain   1:    0.32330 elapsed seconds
# Timing for main: time 2021-12-06_14:39:00 on domain   1:    0.30459 elapsed seconds
# Timing for main: time 2021-12-06_14:42:00 on domain   1:    0.32422 elapsed seconds
# Timing for main: time 2021-12-06_14:45:00 on domain   1:    0.29174 elapsed seconds
# Timing for main: time 2021-12-06_14:48:00 on domain   1:    0.31691 elapsed seconds
# Timing for main: time 2021-12-06_14:51:00 on domain   1:    0.30077 elapsed seconds
# Timing for main: time 2021-12-06_14:54:00 on domain   1:    0.30963 elapsed seconds
# Timing for main: time 2021-12-06_14:57:00 on domain   1:    0.29460 elapsed seconds
# Timing for main: time 2021-12-06_15:00:00 on domain   1:    0.30106 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_15:00:00 for domain        1:    0.08728 elapsed seconds
# Timing for main: time 2021-12-06_15:03:00 on domain   1:    2.17351 elapsed seconds
# Timing for main: time 2021-12-06_15:06:00 on domain   1:    0.32296 elapsed seconds
# Timing for main: time 2021-12-06_15:09:00 on domain   1:    0.29871 elapsed seconds
# Timing for main: time 2021-12-06_15:12:00 on domain   1:    0.31005 elapsed seconds
# Timing for main: time 2021-12-06_15:15:00 on domain   1:    0.30772 elapsed seconds
# Timing for main: time 2021-12-06_15:18:00 on domain   1:    0.32575 elapsed seconds
# Timing for main: time 2021-12-06_15:21:00 on domain   1:    0.33832 elapsed seconds
# Timing for main: time 2021-12-06_15:24:00 on domain   1:    0.36303 elapsed seconds
# Timing for main: time 2021-12-06_15:27:00 on domain   1:    0.30609 elapsed seconds
# Timing for main: time 2021-12-06_15:30:00 on domain   1:    0.32526 elapsed seconds
# Timing for main: time 2021-12-06_15:33:00 on domain   1:    2.32701 elapsed seconds
# Timing for main: time 2021-12-06_15:36:00 on domain   1:    0.34186 elapsed seconds
# Timing for main: time 2021-12-06_15:39:00 on domain   1:    0.30180 elapsed seconds
# Timing for main: time 2021-12-06_15:42:00 on domain   1:    0.36585 elapsed seconds
# Timing for main: time 2021-12-06_15:45:00 on domain   1:    0.32884 elapsed seconds
# Timing for main: time 2021-12-06_15:48:00 on domain   1:    0.29843 elapsed seconds
# Timing for main: time 2021-12-06_15:51:00 on domain   1:    0.35975 elapsed seconds
# Timing for main: time 2021-12-06_15:54:00 on domain   1:    0.36796 elapsed seconds
# Timing for main: time 2021-12-06_15:57:00 on domain   1:    0.33953 elapsed seconds
# Timing for main: time 2021-12-06_16:00:00 on domain   1:    0.34880 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_16:00:00 for domain        1:    0.08890 elapsed seconds
# Timing for main: time 2021-12-06_16:03:00 on domain   1:    2.41190 elapsed seconds
# Timing for main: time 2021-12-06_16:06:00 on domain   1:    0.33062 elapsed seconds
# Timing for main: time 2021-12-06_16:09:00 on domain   1:    0.32903 elapsed seconds
# Timing for main: time 2021-12-06_16:12:00 on domain   1:    0.36901 elapsed seconds
# Timing for main: time 2021-12-06_16:15:00 on domain   1:    0.35422 elapsed seconds
# Timing for main: time 2021-12-06_16:18:00 on domain   1:    0.37266 elapsed seconds
# Timing for main: time 2021-12-06_16:21:00 on domain   1:    0.33763 elapsed seconds
# Timing for main: time 2021-12-06_16:24:00 on domain   1:    0.35038 elapsed seconds
# Timing for main: time 2021-12-06_16:27:00 on domain   1:    0.34640 elapsed seconds
# Timing for main: time 2021-12-06_16:30:00 on domain   1:    0.36443 elapsed seconds
# Timing for main: time 2021-12-06_16:33:00 on domain   1:    2.37278 elapsed seconds
# Timing for main: time 2021-12-06_16:36:00 on domain   1:    0.82169 elapsed seconds
# Timing for main: time 2021-12-06_16:39:00 on domain   1:    0.35434 elapsed seconds
# Timing for main: time 2021-12-06_16:42:00 on domain   1:    0.35438 elapsed seconds
# Timing for main: time 2021-12-06_16:45:00 on domain   1:    0.34002 elapsed seconds
# Timing for main: time 2021-12-06_16:48:00 on domain   1:    0.37318 elapsed seconds
# Timing for main: time 2021-12-06_16:51:00 on domain   1:    0.34220 elapsed seconds
# Timing for main: time 2021-12-06_16:54:00 on domain   1:    0.36050 elapsed seconds
# Timing for main: time 2021-12-06_16:57:00 on domain   1:    0.32454 elapsed seconds
# Timing for main: time 2021-12-06_17:00:00 on domain   1:    0.35596 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_17:00:00 for domain        1:    0.08364 elapsed seconds
# Timing for main: time 2021-12-06_17:03:00 on domain   1:    2.18315 elapsed seconds
# Timing for main: time 2021-12-06_17:06:00 on domain   1:    0.32711 elapsed seconds
# Timing for main: time 2021-12-06_17:09:00 on domain   1:    0.31830 elapsed seconds
# Timing for main: time 2021-12-06_17:12:00 on domain   1:    0.33321 elapsed seconds
# Timing for main: time 2021-12-06_17:15:00 on domain   1:    0.30391 elapsed seconds
# Timing for main: time 2021-12-06_17:18:00 on domain   1:    0.32135 elapsed seconds
# Timing for main: time 2021-12-06_17:21:00 on domain   1:    0.30847 elapsed seconds
# Timing for main: time 2021-12-06_17:24:00 on domain   1:    0.32577 elapsed seconds
# Timing for main: time 2021-12-06_17:27:00 on domain   1:    0.31489 elapsed seconds
# Timing for main: time 2021-12-06_17:30:00 on domain   1:    0.33034 elapsed seconds
# Timing for main: time 2021-12-06_17:33:00 on domain   1:    2.17248 elapsed seconds
# Timing for main: time 2021-12-06_17:36:00 on domain   1:    0.33408 elapsed seconds
# Timing for main: time 2021-12-06_17:39:00 on domain   1:    0.31948 elapsed seconds
# Timing for main: time 2021-12-06_17:42:00 on domain   1:    0.33746 elapsed seconds
# Timing for main: time 2021-12-06_17:45:00 on domain   1:    0.32905 elapsed seconds
# Timing for main: time 2021-12-06_17:48:00 on domain   1:    0.33803 elapsed seconds
# Timing for main: time 2021-12-06_17:51:00 on domain   1:    0.31345 elapsed seconds
# Timing for main: time 2021-12-06_17:54:00 on domain   1:    0.33643 elapsed seconds
# Timing for main: time 2021-12-06_17:57:00 on domain   1:    0.30772 elapsed seconds
# Timing for main: time 2021-12-06_18:00:00 on domain   1:    0.32120 elapsed seconds
# Timing for Writing wrfout_d01_2021-12-06_18:00:00 for domain        1:    0.09046 elapsed seconds
# wrf: SUCCESS COMPLETE WRF
#
#
#
# Plotting Surface Temperatures
# Plotting Precipitation
# Plotting Snow Depth
# Plotting Surface Winds
# Plotting Reference Domains
# ../../run_wrf: line 16: /pi-wrf/Setup/Set_Environment: No such file or directory
# /bin/rm: cannot remove '/pi-wrf/Output/*.png': No such file or directory
# /bin/rm: cannot remove '/pi-wrf/Output/*.gif': No such file or directory
# /bin/rm: cannot remove '/pi-wrf/Output/user_saved_files/*.png': No such file or directory
# /bin/rm: cannot remove '/pi-wrf/Output/Temp_WRF_Output': No such file or directory
# /bin/rm: cannot remove '/pi-wrf/WRF_System/lib/DATA/*': No such file or directory
# ../../run_wrf: line 80: /pi-wrf/WRF_System/lib/DATA/: Is a directory
# ../../run_wrf: line 80: /pi-wrf/WRF_System/lib/DATA/: Is a directory
#  Name of source model =>NCEP GFS Analysis       GRID   3
#  Name of source model =>NCEP GFS Model          GRID   3
# Note: The following floating-point exceptions are signalling: IEEE_OVERFLOW_FLAG IEEE_UNDERFLOW_FLAG

# %% [markdown]
# # Model Output:
# <p>The cells below demonstrate how to retrieve specific plots based on the model output. When the cells are executed, the contents of the Output directory are displayed. These contain the series of plots generated from the model output. The first cell defaults to showing the Your_Domain_Relative plot. The second cell defaults to showing the hourly-temperature_06. You may access any of the available plots in the directory by changing the filename in either of these cells.</p>

# %%
from IPython.display import Image
#Image(filename='test.png') 

# %cd ~/../pi-wrf/Output
# %pwd
# %ls -ls
Image(filename='Your_Domain_Relative.png')
# Out:
# /pi-wrf/Output
# total 7996
# 4008 -rw-r--r-- 1 root root 4102868 Dec  6 22:10 Temp_WRF_Output
#   76 -rw-r--r-- 1 root root   76239 Dec  6 22:12 Your_Domain.png
#   56 -rw-r--r-- 1 root root   53553 Dec  6 22:12 Your_Domain_Relative.png
#  120 -rw-r--r-- 1 root root  119882 Dec  6 22:10 hourly-temperature_00.png
#  120 -rw-r--r-- 1 root root  122086 Dec  6 22:10 hourly-temperature_01.png
#  124 -rw-r--r-- 1 root root  123462 Dec  6 22:10 hourly-temperature_02.png
#  124 -rw-r--r-- 1 root root  123614 Dec  6 22:10 hourly-temperature_03.png
#  124 -rw-r--r-- 1 root root  124965 Dec  6 22:10 hourly-temperature_04.png
#  124 -rw-r--r-- 1 root root  125334 Dec  6 22:10 hourly-temperature_05.png
#  128 -rw-r--r-- 1 root root  127089 Dec  6 22:10 hourly-temperature_06.png
#  120 -rw-r--r-- 1 root root  119337 Dec  6 22:12 hourly-wind_00.png
#  120 -rw-r--r-- 1 root root  121833 Dec  6 22:12 hourly-wind_01.png
#  120 -rw-r--r-- 1 root root  122401 Dec  6 22:12 hourly-wind_02.png
#  124 -rw-r--r-- 1 root root  123379 Dec  6 22:12 hourly-wind_03.png
#  124 -rw-r--r-- 1 root root  123651 Dec  6 22:12 hourly-wind_04.png
#  124 -rw-r--r-- 1 root root  124606 Dec  6 22:12 hourly-wind_05.png
#  124 -rw-r--r-- 1 root root  126611 Dec  6 22:12 hourly-wind_06.png
#  108 -rw-r--r-- 1 root root  110191 Dec  6 22:11 hourly_rain_00.png
#  108 -rw-r--r-- 1 root root  110118 Dec  6 22:11 hourly_rain_01.png
#  108 -rw-r--r-- 1 root root  110200 Dec  6 22:11 hourly_rain_02.png
#  108 -rw-r--r-- 1 root root  110248 Dec  6 22:11 hourly_rain_03.png
#  108 -rw-r--r-- 1 root root  110202 Dec  6 22:11 hourly_rain_04.png
#  112 -rw-r--r-- 1 root root  111281 Dec  6 22:11 hourly_rain_05.png
#  108 -rw-r--r-- 1 root root  108803 Dec  6 22:11 hourly_rain_06.png
#  108 -rw-r--r-- 1 root root  110421 Dec  6 22:11 hourly_snow_00.png
#  108 -rw-r--r-- 1 root root  110314 Dec  6 22:11 hourly_snow_01.png
#  108 -rw-r--r-- 1 root root  110395 Dec  6 22:11 hourly_snow_02.png
#  108 -rw-r--r-- 1 root root  110433 Dec  6 22:11 hourly_snow_03.png
#  108 -rw-r--r-- 1 root root  110417 Dec  6 22:11 hourly_snow_04.png
#  112 -rw-r--r-- 1 root root  111571 Dec  6 22:11 hourly_snow_05.png
#  108 -rw-r--r-- 1 root root  108545 Dec  6 22:11 hourly_snow_06.png
#  120 -rw-r--r-- 1 root root  121065 Dec  6 22:10 low_temp.png
#  128 -rw-r--r-- 1 root root  127378 Dec  6 22:11 max_temp.png
#  128 -rw-r--r-- 1 root root  129324 Dec  6 22:12 max_wind.png
#  108 -rw-r--r-- 1 root root  110516 Dec  6 22:11 rain_total.png
#  128 -rw-r--r-- 1 root root  127140 Dec  6 22:12 snow_total.png
#    4 drwxr-xr-x 2 root root    4096 Jul  1 03:12 user_saved_files/

# %%
from IPython.display import Image
#Image(filename='test.png') 

#%cd ../../Output
# %pwd
# %ls -ls
Image(filename='hourly-temperature_06.png')
# Out:
# total 8024
# 4008 -rw-r--r-- 1 root root 4102868 Dec  1 21:32 Temp_WRF_Output
#   76 -rw-r--r-- 1 root root   76239 Dec  1 21:34 Your_Domain.png
#   56 -rw-r--r-- 1 root root   53553 Dec  1 21:34 Your_Domain_Relative.png
#  128 -rw-r--r-- 1 root root  126999 Dec  1 21:33 hourly-temperature_00.png
#  128 -rw-r--r-- 1 root root  127576 Dec  1 21:33 hourly-temperature_01.png
#  128 -rw-r--r-- 1 root root  127260 Dec  1 21:33 hourly-temperature_02.png
#  128 -rw-r--r-- 1 root root  127718 Dec  1 21:33 hourly-temperature_03.png
#  124 -rw-r--r-- 1 root root  126974 Dec  1 21:33 hourly-temperature_04.png
#  124 -rw-r--r-- 1 root root  125688 Dec  1 21:33 hourly-temperature_05.png
#  124 -rw-r--r-- 1 root root  124196 Dec  1 21:33 hourly-temperature_06.png
#  124 -rw-r--r-- 1 root root  124545 Dec  1 21:34 hourly-wind_00.png
#  124 -rw-r--r-- 1 root root  124447 Dec  1 21:34 hourly-wind_01.png
#  124 -rw-r--r-- 1 root root  126634 Dec  1 21:34 hourly-wind_02.png
#  128 -rw-r--r-- 1 root root  127223 Dec  1 21:34 hourly-wind_03.png
#  128 -rw-r--r-- 1 root root  127113 Dec  1 21:34 hourly-wind_04.png
#  124 -rw-r--r-- 1 root root  126792 Dec  1 21:34 hourly-wind_05.png
#  124 -rw-r--r-- 1 root root  126200 Dec  1 21:34 hourly-wind_06.png
#  108 -rw-r--r-- 1 root root  110086 Dec  1 21:33 hourly_rain_00.png
#  108 -rw-r--r-- 1 root root  110008 Dec  1 21:33 hourly_rain_01.png
#  108 -rw-r--r-- 1 root root  110079 Dec  1 21:33 hourly_rain_02.png
#  108 -rw-r--r-- 1 root root  110129 Dec  1 21:33 hourly_rain_03.png
#  108 -rw-r--r-- 1 root root  110091 Dec  1 21:33 hourly_rain_04.png
#  108 -rw-r--r-- 1 root root  110097 Dec  1 21:33 hourly_rain_05.png
#  108 -rw-r--r-- 1 root root  110155 Dec  1 21:33 hourly_rain_06.png
#  108 -rw-r--r-- 1 root root  110276 Dec  1 21:33 hourly_snow_00.png
#  108 -rw-r--r-- 1 root root  110196 Dec  1 21:34 hourly_snow_01.png
#  108 -rw-r--r-- 1 root root  110273 Dec  1 21:34 hourly_snow_02.png
#  108 -rw-r--r-- 1 root root  110306 Dec  1 21:34 hourly_snow_03.png
#  108 -rw-r--r-- 1 root root  110294 Dec  1 21:34 hourly_snow_04.png
#  108 -rw-r--r-- 1 root root  110281 Dec  1 21:34 hourly_snow_05.png
#  108 -rw-r--r-- 1 root root  110324 Dec  1 21:34 hourly_snow_06.png
#  124 -rw-r--r-- 1 root root  126642 Dec  1 21:33 low_temp.png
#  124 -rw-r--r-- 1 root root  124273 Dec  1 21:33 max_temp.png
#  128 -rw-r--r-- 1 root root  130770 Dec  1 21:34 max_wind.png
#  112 -rw-r--r-- 1 root root  111946 Dec  1 21:33 rain_total.png
#  120 -rw-r--r-- 1 root root  120652 Dec  1 21:34 snow_total.png
#    4 drwxr-xr-x 2 root root    4096 Jul  1 03:12 user_saved_files/

# %%
from IPython.display import Image
#Image(filename='test.png') 

#%cd ../../Output
# %pwd
# %ls -ls
Image(filename='hourly-wind_06.png')
# Out:
# total 7996
# 4008 -rw-r--r-- 1 root root 4102868 Dec  6 22:10 Temp_WRF_Output
#   76 -rw-r--r-- 1 root root   76239 Dec  6 22:12 Your_Domain.png
#   56 -rw-r--r-- 1 root root   53553 Dec  6 22:12 Your_Domain_Relative.png
#  120 -rw-r--r-- 1 root root  119882 Dec  6 22:10 hourly-temperature_00.png
#  120 -rw-r--r-- 1 root root  122086 Dec  6 22:10 hourly-temperature_01.png
#  124 -rw-r--r-- 1 root root  123462 Dec  6 22:10 hourly-temperature_02.png
#  124 -rw-r--r-- 1 root root  123614 Dec  6 22:10 hourly-temperature_03.png
#  124 -rw-r--r-- 1 root root  124965 Dec  6 22:10 hourly-temperature_04.png
#  124 -rw-r--r-- 1 root root  125334 Dec  6 22:10 hourly-temperature_05.png
#  128 -rw-r--r-- 1 root root  127089 Dec  6 22:10 hourly-temperature_06.png
#  120 -rw-r--r-- 1 root root  119337 Dec  6 22:12 hourly-wind_00.png
#  120 -rw-r--r-- 1 root root  121833 Dec  6 22:12 hourly-wind_01.png
#  120 -rw-r--r-- 1 root root  122401 Dec  6 22:12 hourly-wind_02.png
#  124 -rw-r--r-- 1 root root  123379 Dec  6 22:12 hourly-wind_03.png
#  124 -rw-r--r-- 1 root root  123651 Dec  6 22:12 hourly-wind_04.png
#  124 -rw-r--r-- 1 root root  124606 Dec  6 22:12 hourly-wind_05.png
#  124 -rw-r--r-- 1 root root  126611 Dec  6 22:12 hourly-wind_06.png
#  108 -rw-r--r-- 1 root root  110191 Dec  6 22:11 hourly_rain_00.png
#  108 -rw-r--r-- 1 root root  110118 Dec  6 22:11 hourly_rain_01.png
#  108 -rw-r--r-- 1 root root  110200 Dec  6 22:11 hourly_rain_02.png
#  108 -rw-r--r-- 1 root root  110248 Dec  6 22:11 hourly_rain_03.png
#  108 -rw-r--r-- 1 root root  110202 Dec  6 22:11 hourly_rain_04.png
#  112 -rw-r--r-- 1 root root  111281 Dec  6 22:11 hourly_rain_05.png
#  108 -rw-r--r-- 1 root root  108803 Dec  6 22:11 hourly_rain_06.png
#  108 -rw-r--r-- 1 root root  110421 Dec  6 22:11 hourly_snow_00.png
#  108 -rw-r--r-- 1 root root  110314 Dec  6 22:11 hourly_snow_01.png
#  108 -rw-r--r-- 1 root root  110395 Dec  6 22:11 hourly_snow_02.png
#  108 -rw-r--r-- 1 root root  110433 Dec  6 22:11 hourly_snow_03.png
#  108 -rw-r--r-- 1 root root  110417 Dec  6 22:11 hourly_snow_04.png
#  112 -rw-r--r-- 1 root root  111571 Dec  6 22:11 hourly_snow_05.png
#  108 -rw-r--r-- 1 root root  108545 Dec  6 22:11 hourly_snow_06.png
#  120 -rw-r--r-- 1 root root  121065 Dec  6 22:10 low_temp.png
#  128 -rw-r--r-- 1 root root  127378 Dec  6 22:11 max_temp.png
#  128 -rw-r--r-- 1 root root  129324 Dec  6 22:12 max_wind.png
#  108 -rw-r--r-- 1 root root  110516 Dec  6 22:11 rain_total.png
#  128 -rw-r--r-- 1 root root  127140 Dec  6 22:12 snow_total.png
#    4 drwxr-xr-x 2 root root    4096 Jul  1 03:12 user_saved_files/

# %%
print("Hello new world!")
# Out:
# Hello new world!

# %%
from matplotlib.animation import FuncAnimation
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def wind_animate(i):
    
    filename = "hourly-wind_0" + str(i) + ".png"
    nparr_imgdata = mpimg.imread(filename)
    ax = fig.gca()
    ax.imshow(nparr_imgdata)

# %%
fig, ax = plt.subplots()
nparr_initimg = mpimg.imread("hourly-wind_00.png")
ax.imshow(nparr_initimg)

# %%
from PIL import Image
anim = FuncAnimation(fig, wind_animate, frames=5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-7d503a81c479> in <module>
#       1 from PIL import Image
# ----> 2 from PIL import ffmpeg
#       3 anim = FuncAnimation(fig, wind_animate, frames=5)
#
# ImportError: cannot import name 'ffmpeg'

# %%
anim.save("test.gif", writer="pillow")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/animation.py:971: UserWarning: MovieWriter pillow unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)

# %%
from matplotlib import rc
rc('animation', html='html5')
anim
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/lib/python3/dist-packages/matplotlib/animation.py in _repr_html_(self)
#    1183         fmt = rcParams['animation.html']
#    1184         if fmt == 'html5':
# -> 1185             return self.to_html5_video()
#    1186
#    1187
#
# /usr/lib/python3/dist-packages/matplotlib/animation.py in to_html5_video(self)
#    1153                 # We create a writer manually so that we can get the
#    1154                 # appropriate size for the tag
# -> 1155                 Writer = writers[rcParams['animation.writer']]
#    1156                 writer = Writer(codec='h264',
#    1157                                 bitrate=rcParams['animation.bitrate'],
#
# /usr/lib/python3/dist-packages/matplotlib/animation.py in __getitem__(self, name)
#     128         if not self.avail:
#     129             raise RuntimeError("No MovieWriters available!")
# --> 130         return self.avail[name]
#     131
#     132 writers = MovieWriterRegistry()
#
# KeyError: 'ffmpeg'
